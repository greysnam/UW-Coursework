# %% [markdown]
# ## Cleaning and Grouping
#
# ## Part 1: Loading the Data
# Using the [adult income dataset](https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data) we used in HW1, we're going to create more function to take care of all the data munging strategies we learned today.
#
# Read in the dataframe:

# %% [markdown]
# ### Grace Nam MSIS Gold

# %%
import pandas as pd

adult_df = pd.read_csv(r"C:\Users\eunn\Downloads\adult.data", header=None, engine='python')

## I had to add engine='python' because it was displaying an error message telling me to. Do you know why I had to do 
## do this? I used this same code with out engine='python' in the last homework and it worked fine!

# %% [markdown]
# Now add the following list of column names: Add the following column names:
# `["age$$", "workclass!!", "fnlwgt", "education", "education_num", "marital-status", "occupation", "relationship", "race", "sex","capital_gain", "capital_loss", "hours_per_week", "native_country", "income"]`

# %%
adult_df.columns = ["age$$", "workclass!!", "fnlwgt", "education", "education_num", "marital-status", \
                    "occupation", "relationship", "race", "sex","capital_gain", "capital_loss", \
                    "hours_per_week", "native_country", "income"]
adult_df.head()
# Out:
#    age$$        workclass!!  fnlwgt   education  education_num  \
# 0     39          State-gov   77516   Bachelors             13
# 1     50   Self-emp-not-inc   83311   Bachelors             13
# 2     38            Private  215646     HS-grad              9
# 3     53            Private  234721        11th              7
# 4     28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# ...

# %% [markdown]
# ## Part 2: Creating Data Munging Functions
# Create one function to perform each of the following tasks:
# #### 1. Remove symbols from column headers
#     - This function should take in a dataframe and a symbol to remove as arguments
#     - It should remove the symbol from all column names
#
# #### 2. Replace missing numeric values with the column mean
#     - This function should take in a dataframe and column names as arguments
#     - For the specified integer column, it should replace any null values with the mean for the column
#
# Write those functions below:

# %%
# remove symbols from column headers
def clean_symbols(df,sym):
    df.columns = df.columns.str.replace(sym,'')
    return df

# %%
# replace missing numeric values with the column mean 
def replace_null(df,col):
    df = df[col].fillna(df[col].mean(),inplace=True)
    return df

# %% [markdown]
# ## Part 3: Apply the functions to the adult dataset
# Apply each of your functions to the adult dataset. Check to make sure they worked properly.

# %%
clean_symbols(adult_df,'$')
clean_symbols(adult_df,'!')
# Out:
#        age          workclass  fnlwgt      education  education_num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 4       28            Private  338409      Bachelors             13
# 5       37            Private  284582        Masters             14
# 6       49            Private  160187            9th              5
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# 8       31            Private   45781        Masters             14
# 9       42            Private  159449      Bachelors             13
# 10      37            Private  280464   Some-college             10
# 11      30          State-gov  141297      Bachelors             13
# 12      23            Private  122272      Bachelors             13
# ...

# %%
replace_null(adult_df,'age')
adult_df
# Out:
#        age          workclass  fnlwgt      education  education_num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 4       28            Private  338409      Bachelors             13
# 5       37            Private  284582        Masters             14
# 6       49            Private  160187            9th              5
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# 8       31            Private   45781        Masters             14
# 9       42            Private  159449      Bachelors             13
# 10      37            Private  280464   Some-college             10
# 11      30          State-gov  141297      Bachelors             13
# 12      23            Private  122272      Bachelors             13
# ...

# %% [markdown]
# ## Part 4: Grouping
# Group the adult dataset by education and calculate the mean age for each group.

# %%
adult_education = adult_df.groupby("education")
adult_education["age"].mean()
# Out:
# education
#  10th            37.429796
#  11th            32.355745
#  12th            32.000000
#  1st-4th         46.142857
#  5th-6th         42.885886
#  7th-8th         48.445820
#  9th             41.060311
#  Assoc-acdm      37.381443
#  Assoc-voc       38.553546
#  Bachelors       38.904949
#  Doctorate       47.702179
#  HS-grad         38.974479
#  Masters         44.049913
#  Preschool       42.764706
#  Prof-school     44.746528
#  Some-college    35.756275
# Name: age, dtype: float64

# %% [markdown]
# ## Part 5: Apply these functions to your final project dataset
# Apply each of the functions above to your dataset.

# %%
my_dataset = pd.read_csv(r"C:\Users\eunn\Downloads\student\student-mat.csv")
my_dataset.head()
# Out:
#   school sex  age! address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F  18.0       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   NaN       U     GT3       T     1     1  at_home     other
# 2     GP   F  15.0       U     LE3       T     1     1  at_home     other
# 3     GP   F  15.0       U     GT3       T     4     2   health  services
# 4     GP   F  16.0       U     GT3       T     3     3    other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# 1  ...      5        3      3     1     1      3        4   5   5   6
# 2  ...      4        3      2     2     3      3       10   7   8  10
# 3  ...      3        2      2     1     1      5        2  15  14  15
# 4  ...      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
clean_symbols(my_dataset,'!')
# there weren't any symbols in the original dataset, but I added an "!" in the age column in the excel spreadsheet
# just to make sure this function is working properly.
my_dataset.head()
# Out:
#   school sex   age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F  18.0       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   NaN       U     GT3       T     1     1  at_home     other
# 2     GP   F  15.0       U     LE3       T     1     1  at_home     other
# 3     GP   F  15.0       U     GT3       T     4     2   health  services
# 4     GP   F  16.0       U     GT3       T     3     3    other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# 1  ...      5        3      3     1     1      3        4   5   5   6
# 2  ...      4        3      2     2     3      3       10   7   8  10
# 3  ...      3        2      2     1     1      5        2  15  14  15
# 4  ...      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
replace_null(my_dataset, "age")
# there weren't any nulls in the original dataset, so I added a "NaN" in row 1 under age column to test it out. 
my_dataset.head()
# Out:
#   school sex        age address famsize Pstatus  Medu  Fedu     Mjob  \
# 0     GP   F  18.000000       U     GT3       A     4     4  at_home
# 1     GP   F  16.695431       U     GT3       T     1     1  at_home
# 2     GP   F  15.000000       U     LE3       T     1     1  at_home
# 3     GP   F  15.000000       U     GT3       T     4     2   health
# 4     GP   F  16.000000       U     GT3       T     3     3    other
#
#        Fjob  ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  \
# 0   teacher  ...      4        3      4     1     1      3        6   5   6
# 1     other  ...      5        3      3     1     1      3        4   5   5
# 2     other  ...      4        3      2     2     3      3       10   7   8
# 3  services  ...      3        2      2     1     1      5        2  15  14
# 4     other  ...      4        3      2     1     2      5        4   6  10
#
#    G3
# 0   6
# 1   6
# 2  10
# 3  15
# 4  10
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Part 6: Use groupby to answer two questions about your dataset that you will use in your final project.

# %%
##  How does free time after school affect students' final grade in math (G3)? 
my_dataset_freetime = my_dataset.groupby("freetime")
my_dataset_freetime["G3"].mean()
# Out:
# freetime
# 1     9.842105
# 2    11.562500
# 3     9.783439
# 4    10.426087
# 5    11.300000
# Name: G3, dtype: float64

# %%
##  How does family size affect students' final grade in math (G3)? 
my_dataset_famsize = my_dataset.groupby("famsize")
my_dataset_famsize["G3"].mean()
# Out:
# famsize
# GT3    10.177936
# LE3    11.000000
# Name: G3, dtype: float64
